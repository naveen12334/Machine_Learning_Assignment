# %% [markdown]
# # Assignment_17

# %% [markdown]
# # 1. Using a graph to illustrate slope and intercept, define basic linear regression.

# %%
# Ans-> The equation y=mx+c represents a straight line graphically, where m is its slope/gradient and c its intercept.
#       In this code, I am plotting y=mx+b  with Matplotlib.
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-5,5,100)
y = 2*x+1
plt.plot(x, y, '-r', label='y=2x+1')
plt.title('Graph of y=2x+1')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %% [markdown]
# # 2. In a graph, explain the terms rise, run, and slope.

# %% [markdown]
# Ans->The slope of a line measures the steepness of the line. Most of we are probably familiar with associating slope with
# "rise over run". Rise means how many units we move up or down from point to point. On the graph that would be a change
#  in the y values. Run means how far left or right we move from point to point.

# %% [markdown]
# # 3. Use a graph to demonstrate slope, linear positive slope, and linear negative slope, as well as the different conditions that contribute to the slope.

# %%
# Ans-> The steepness of a hill is called a slope. The same goes for the steepness of a line. The slope is defined as the
#       ratio of the vertical change between two points, the rise, to the horizontal change between the same two points, 
#       the run.
#       slope=rise/run=changeiny/changeinx
#       The slope of a line is usually represented by the letter m. (x1, y1) represents the first point whereas (x2, y2) 
#       represents the second point.
#       m=y2−y1/x2−x1
#       It is important to keep the x-and y-coordinates in the same order in both the numerator and the denominator otherwise
#       we will get the wrong slope.

# %% [markdown]
# ![g1.png](attachment:g1.png)

# %% [markdown]
# # 4. Use a graph to demonstrate curve linear negative slope and curve linear positive slope.

# %% [markdown]
# Ans->Image result for a graph to demonstrate curve linear negative slope and curve linear positive slope.I
# f the signs are different then the answer is negative! If the slope is negative we can plot our next point by going
# down and right OR up and left. If the slope is positive we can plot our next point by going up and right OR down and
# left.

# %% [markdown]
# # 5. Use a graph to show the maximum and low points of curves.

# %% [markdown]
# Ans->To find the maximum/minimum of a curve we must first differentiate the function and then equate it to zero. This gives
# us one coordinate. To find the other we must resubstitute the one already found into the original function.

# %% [markdown]
# # 6. Use the formulas for a and b to explain ordinary least squares.

# %% [markdown]
# Ans->This best line is the Least Squares Regression Line (abbreviated as LSRL). This is true where ˆy is the predicted
# y-value given x, a is the y intercept, b and is the slope. For every x-value, the Least Squares Regression Line makes
# a predicted y-value that is close to the observed y-value, but usually slightly off.

# %% [markdown]
# # 7. Provide a step-by-step explanation of the OLS algorithm.

# %% [markdown]
# Ans->
# Ordinary Least Square Method
#
# Set a difference between dependent variable and its estimation
#
# Square the difference
#
# Take summation for all data
#
# To get the parameters that make the sum of square difference become minimum, take partial derivative for each parameter
# and equate it with zero

# %% [markdown]
# # 8. What is the regression&#39;s standard error? To represent the same, make a graph.

# %% [markdown]
# Ans->The standard error of the regression (S), also known as the standard error of the estimate, represents the average
# distance that the observed values fall from the regression line. Conveniently, it tells us how wrong the regression
# model is on average using the units of the response variable.

# %% [markdown]
# ![2linear.png](attachment:2linear.png)

# %% [markdown]
# # 9. Provide an example of multiple linear regression.

# %% [markdown]
# Ans-> Multiple Linear Regression is one of the important regression algorithms which predicts the linear relationship between
# a single dependent continuous variable and more than one independent variable. Example: Prediction of CO2 emission
# based on engine size and number of cylinders in a car.

# %% [markdown]
# # 10. Describe the regression analysis assumptions and the BLUE principle.

# %% [markdown]
# Ans->There are four assumptions associated with a linear regression model:
#
# 1.Linearity: The relationship between X and the mean of Y is linear.
#
# 2.Homoscedasticity: The variance of residual is the same for any value of X.
#
# 3.Independence: Observations are independent of each other.
#
# 4.BLUE is an acronym for the following: Best Linear Unbiased Estimator. In this context, the definition of “best” refers
# to the minimum variance or the narrowest sampling distribution.

# %% [markdown]
# # 11. Describe two major issues with regression analysis.

# %% [markdown]
# Ans->It involves very lengthy and complicated procedure of calculations and analysis. It cannot be used in case of
# qualitative phenomenon viz. honesty, crime etc.
#
# The overall idea of regression is to examine two things:
#
# (1) does a set of predictor variables do a good job in
# predicting an outcome (dependent) variable?
#
# (2) Which variables in particular are significant predictors of the outcome
# variable, and in what way do they–indicated by the magnitude and sign of the beta

# %% [markdown]
# # 12. How can the linear regression model&#39;s accuracy be improved?

# %% [markdown]
# Ans-> 8 Methods to Boost the Accuracy of a Model->
#
#  a) Add more data. Having more data is always a good idea.
#
#  b) Treat missing and Outlier values.
#
#  c) Feature Engineering.
#
#  d) Feature Selection.
#
#  e) Multiple algorithms.
#
#  f) Algorithm Tuning.
#
#  g) Ensemble methods.

# %% [markdown]
# # 13. Using an example, describe the polynomial regression model in detail.

# %% [markdown]
# Ans->In statistics, polynomial regression is a form of regression analysis in which the relationship between the independent
# variable x and the dependent variable y is modelled as an nth degree polynomial in x.For this reason, polynomial
# regression is considered to be a special case of multiple linear regression.
#
# Polynomial regression is one of the machine learning algorithms used for making predictions. For example, it is widely
# applied to predict the spread rate of COVID-19 and other infectious diseases.

# %% [markdown]
# # 14. Provide a detailed explanation of logistic regression.

# %% [markdown]
# Ans->Logistic regression is a statistical analysis method used to predict a data value based on prior observations of a
# data set.Based on historical data about earlier outcomes involving the same input criteria, it then scores new cases
# on their probability of falling into a particular outcome category.

# %% [markdown]
# # 15. What are the logistic regression assumptions?

# %% [markdown]
# Ans->Basic assumptions that must be met for logistic regression include independence of errors, linearity in the logistic for
# continuous variables, absence of multicollinearity, and lack of strongly influential outliers.

# %% [markdown]
# # 16. Go through the details of maximum likelihood estimation.

# %% [markdown]
# Ans-> Maximum likelihood estimation is a method that determines values for the parameters of a model. The parameter values
# are found such that they maximise the likelihood that the process described by the model produced the data that were
# actually observed.
